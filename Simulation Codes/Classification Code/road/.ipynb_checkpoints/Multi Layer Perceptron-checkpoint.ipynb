# %%
import rasterio
from rasterio.plot import show
import os.path
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
# function to convert txt into array of dataset --> returns array and size of data
def create_data (file, Class):
    
    arr = []
    x = -1
    for line in file:
        x = x+1
        if (x == 0):
            continue
        
        a = line.strip().split()
        for i in range(len(a)-7):
            arr.append(a[i+4])
        arr.append(Class)
    
    return arr, x

# inp is input array and count is the count of data
inp = []
count = 0    

# Building
file = open(r'u1.txt')
arr, x = create_data(file,0)
inp += arr
count += x

# Vegetation
file = open(r'v1.txt')
arr, x = create_data(file,0)
inp += arr
count += x

# Road
file = open(r'r1.txt')
arr, x = create_data(file,1)
inp += arr
count += x

# Barren Land
file = open(r'b1.txt')
arr, x = create_data(file,0)
inp += arr
count += x

print(count)
a = np.array(inp)
inp = a.reshape(count,14)
inp
# Out:
# 667
# array([['0.0846', '0.1062', '0.136', ..., '0.1995', '0.021319496', '0'],
#        ['0.0834', '0.086', '0.1096', ..., '0.1699', '0.038092006', '0'],
#        ['0.0834', '0.0628', '0.0826', ..., '0.1699', '0.020233555', '0'],
#        ...,
#        ['0.0493', '0.0744', '0.1074', ..., '0.2082', '0.01878243', '0'],
#        ['0.0493', '0.076', '0.1068', ..., '0.2082', '0.020953394', '0'],
#        ['0.0493', '0.0742', '0.107', ..., '0.2082', '0.017414233', '0']],
#       dtype='<U13')

# %%
DF = pd.DataFrame(inp)
 
# save the dataframe as a csv file
DF.to_csv("data1.csv")
DF.columns =['B1', 'B2' ,'B3', 'B4','B5', 'B6','B7', 'B8','B8A', 'B9', 'B11', 'B12', 'PISI', 'Out']

DF.head(1000)
# Out:
#          B1      B2      B3      B4      B5      B6      B7      B8     B8A  \
# 0    0.0846  0.1062   0.136  0.1582  0.1611  0.2195  0.2442  0.2453  0.2451
# 1    0.0834   0.086  0.1096   0.115  0.1306  0.1834  0.2005  0.1872  0.2297
# 2    0.0834  0.0628  0.0826  0.0802  0.1306  0.1834  0.2005  0.1852  0.2297
# 3     0.081  0.0984  0.1322  0.1406  0.1651  0.1874  0.1987  0.1966  0.2164
# 4     0.081  0.1192   0.152  0.1686  0.1651  0.1874  0.1987  0.2154  0.2164
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 662  0.0482  0.0805  0.1078  0.1276  0.1478  0.1845  0.2039  0.2056   0.228
# 663    0.05  0.0766   0.109  0.1294  0.1474  0.1929  0.2129  0.2008  0.2271
# 664  0.0493  0.0744  0.1074  0.1322  0.1511  0.1866   0.204  0.2043  0.2206
# 665  0.0493   0.076  0.1068  0.1316  0.1511  0.1866   0.204  0.2028  0.2206
# 666  0.0493  0.0742   0.107  0.1302  0.1511  0.1866   0.204  0.2064  0.2206
#
#          B9     B11     B12         PISI Out
# 0    0.2379  0.2327  0.1995  0.021319496   0
# 1    0.2379  0.2188  0.1699  0.038092006   0
# 2    0.2379  0.2188  0.1699  0.020233555   0
# 3    0.2239  0.2195  0.1751  0.042859174   0
# 4    0.2239  0.2195  0.1751  0.049116742   0
# ..      ...     ...     ...          ...  ..
# 662  0.2701  0.2484  0.2017  0.023034003   0
# 663  0.2534  0.2445  0.1996  0.022591919   0
# 664  0.2534   0.251  0.2082   0.01878243   0
# 665  0.2534   0.251  0.2082  0.020953394   0
# 666  0.2534   0.251  0.2082  0.017414233   0
#
# [667 rows x 14 columns]

# %%
X = DF.drop('Out',axis = 1)
Y = DF['Out']

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(activation = 'tanh',hidden_layer_sizes=(1000,500,100,100), max_iter=3000000)
model.fit(X,Y)
pred1 = model.predict(X)
print(accuracy_score(pred1,Y))
print(confusion_matrix(Y, pred1))
# Out:
# 0.9955022488755623
# [[553   2]
#  [  1 111]]

# %%
#?MLPClassifier

# %%
img2 = rasterio.open("test1.tif")
z2 = img2.read()

z2.shape
# Out:
# (16, 173, 118)

# %%
inp2 = []
for i in range(173):
    for j in range(118):
        for k in range(13):
            inp2.append(z2[k,i,j])
        #inp.append(ndvi[i,j])

print(len(inp2))

a = np.array(inp2)
inp2 = a.reshape(173*118,13)
inp2.shape
# Out:
# 265382
# (20414, 13)

# %%
import pandas as pd
DF2 = pd.DataFrame(inp2)
 
# save the dataframe as a csv file
DF2.to_csv("data2.csv")
DF2.columns =['B1', 'B2' ,'B3', 'B4','B5', 'B6','B7', 'B8','B8A', 'B9', 'B11', 'B12', 'PISI']

DF2.head(15)
# Out:
#         B1      B2      B3      B4      B5      B6      B7      B8     B8A  \
# 0   0.0414  0.0471  0.0749  0.0584  0.1053  0.2325  0.2701  0.2830  0.2953
# 1   0.0414  0.0436  0.0726  0.0602  0.1053  0.2325  0.2701  0.2776  0.2953
# 2   0.0444  0.0436  0.0716  0.0582  0.1070  0.2272  0.2632  0.2723  0.2828
# 3   0.0444  0.0484  0.0722  0.0656  0.1070  0.2272  0.2632  0.2570  0.2828
# 4   0.0469  0.0756  0.1126  0.0952  0.1208  0.2276  0.2693  0.2592  0.2861
# 5   0.0469  0.0617  0.0854  0.0994  0.1208  0.2276  0.2693  0.2822  0.2861
# 6   0.0469  0.0617  0.0854  0.0994  0.1208  0.2276  0.2693  0.2822  0.2861
# 7   0.0491  0.0458  0.0762  0.0647  0.1302  0.2138  0.2568  0.2778  0.2657
# 8   0.0491  0.0542  0.0786  0.0769  0.1302  0.2138  0.2568  0.2489  0.2657
# 9   0.0532  0.0632  0.0866  0.0954  0.1301  0.1710  0.1837  0.2174  0.2022
# 10  0.0532  0.0608  0.0891  0.1110  0.1301  0.1710  0.1837  0.1782  0.2022
# 11  0.0616  0.0625  0.0938  0.1152  0.1415  0.2054  0.2210  0.1782  0.2466
# 12  0.0616  0.0588  0.0915  0.0977  0.1415  0.2054  0.2210  0.2431  0.2466
# 13  0.0713  0.0498  0.0854  0.0756  0.1379  0.2424  0.2755  0.2961  0.2939
# 14  0.0713  0.0504  0.0863  0.0788  0.1379  0.2424  0.2755  0.2806  0.2939
#
#         B9     B11     B12      PISI
# 0   0.2912  0.1742  0.0925 -0.048716
# 1   0.2912  0.1742  0.0925 -0.048486
# 2   0.2912  0.1808  0.1044 -0.045447
# 3   0.2912  0.1808  0.1044 -0.032740
# 4   0.2912  0.1958  0.1265 -0.011720
# 5   0.2912  0.1958  0.1265 -0.036297
# 6   0.2912  0.1958  0.1265 -0.036297
# 7   0.2800  0.2015  0.1419 -0.046799
# 8   0.2800  0.2015  0.1419 -0.023344
# 9   0.2800  0.2096  0.1739  0.002095
# 10  0.2800  0.2096  0.1739  0.022610
# 11  0.2800  0.2298  0.1759  0.024002
# 12  0.2800  0.2298  0.1759 -0.016249
# 13  0.2867  0.2359  0.1569 -0.054017
# 14  0.2867  0.2359  0.1569 -0.044636

# %%
pred_22 = model.predict(DF2)
pred_22
# Out:
# array(['0', '0', '0', ..., '0', '1', '1'], dtype='<U1')

# %%
a = np.array(pred_22)
pred_22 = a.reshape(173,118)

img = np.array(pred_22, dtype=np.uint8)
type(img[0,0])
img = img*255

print(img[0,40],pred_22[0,40])
print(img[25,0],pred_22[150,0])
#print(img[0,6],pred_22[0,6])

img3 = Image.fromarray(img)
img3.save('nn22.png')
show(img3)
# Out:
# 0 0
# 255 0
# <AxesSubplot:>
