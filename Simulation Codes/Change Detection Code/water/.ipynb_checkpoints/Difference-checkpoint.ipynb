# %%
import rasterio
from rasterio.plot import show
import os.path
import numpy as np
import pandas as pd
from PIL import Image

# %%
img1 = rasterio.open("nn16-11-19.png")
img2 = rasterio.open("nn6-12-19.png")

show(img1, cmap='gray')
show(img2, cmap='gray')
# Out:
# C:\Users\Akshansh\anaconda3\lib\site-packages\rasterio\__init__.py:334: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# <AxesSubplot:>

# %%
z1 = img1.read()
print(z1.shape)
z2 = img2.read()
print(z2.shape)
# Out:
# (1, 316, 226)
# (1, 316, 226)

# %%
a = np.array(z1)
pred1 = a.reshape(316,226)
rslt = np.unique(pred1)
print(rslt)
a = np.array(z2)
pred2 = a.reshape(316,226)
rslt = np.unique(pred2)
print(rslt)
temp1 = pred2 - pred1
#"""
for i in range(316):
    for j in range(118):
        if(temp1[i][j]==1):
            temp1[i][j]=0
#"""
rslt = np.unique(temp1)

print(rslt)
img3 = Image.fromarray(temp1)
img3.save('nn_change.png' )
show(img3,cmap='gray')
temp1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16704\2079600261.py in <module>
#       1 a = np.array(z1)
# ----> 2 pred1 = a.reshape(173,118)
#       3 rslt = np.unique(pred1)
#       4 print(rslt)
#       5 a = np.array(z2)
#
# ValueError: cannot reshape array of size 71416 into shape (173,118)
